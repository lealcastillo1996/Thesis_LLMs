# %% [markdown]
# <a href="https://colab.research.google.com/github/lealcastillo1996/Thesis_LLMs/blob/main/2_OpenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Installing langchain
# !pip install langchain==0.0.166
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.5/803.5 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 5.6 MB/s eta 0:00:00
# ...

# %%
#Installing required libraries
# !pip install openai chromadb pypdf panel notebook
# !pip install tiktoken
# !pip install huggingface_hub
# !pip install transformers
# # Install package
# !pip install "unstructured[local-inference]"
# !pip install layoutparser[layoutmodels,tesseract]
# !pip install nltk
# !pip install Pillow==9.0.0
# !pip install beautifulsoup4
# !pip install googlesearch-python
# !pip install requests
# !pip install lxml
# !pip install trafilatura
# !pip install sentence_transformers
# !pip install numba
#Reset device
import torch
from numba import cuda
device = cuda.get_current_device()
device.reset()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.3/249.3 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 7.8 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.1/965.1 kB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 95.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 86.3 MB/s eta 0:00:00
# ...

# %%
#Imports
import os
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
from langchain.document_loaders import TextLoader
from langchain.document_loaders import PyPDFLoader
from langchain.schema import Document
#from langchain.indexes import VectorstoreIndexCreator
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceHubEmbeddings
from langchain.docstore.document import Document
from langchain.document_loaders import UnstructuredFileLoader
from langchain.docstore.document import Document
from langchain.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.docstore.document import Document
from langchain.prompts import PromptTemplate
from langchain.indexes.vectorstore import VectorstoreIndexCreator
from langchain.chains.question_answering import load_qa_chain
from langchain.prompts import PromptTemplate
from langchain import PromptTemplate, LLMChain
#Libraries to use
import requests
from bs4 import BeautifulSoup
import trafilatura
from googlesearch import search
import string
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')

"""models and embeddings download"""
#Emneddings for context search
from sentence_transformers import SentenceTransformer, util
import torch
embedder = SentenceTransformer('all-MiniLM-L6-v2')

#OPEN AI EMBEDDINGS
openai = OpenAIEmbeddings(openai_api_key="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")
import os
os.environ["OPENAI_API_KEY"] = "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"
from langchain.llms.base import LLM
from transformers import pipeline
import torch
open_ai = OpenAI(temperature = 0, model_name="gpt-3.5-turbo")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ...
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:169: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:696: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(

# %%
#Aditional context
aditional_context= """
Who is your creator? = SUE.
Who created you? = I was created by SUE.
Who coded you? =I was coded by SUE.
What is your name?= My name is Suesie Chatbot.
What is your purpose? My purpose is to assist users in how to use Kubernetes.
Who are you? = I am a chatbot called Suesie, i was created by SUE and my purpose is to assist users in how to use Kubernetes.
What is the chatbot source of information? = The chatbot has been trained on the entire Kubernetes documentation and can also retrieve information from the internet.
"""

# %% [markdown]
# #Function definition

# %%
get_base = 0
base =0
base_chunks =  0




from logging import exception
#Function to seach in internet
def search_internet(query):
  #Seach in google top links related to the query
  # to search
  query_context = ""
  query_input = query
  query = query_context + query_input
  try:
    links = []
    for j in search(query,3):
        links.append(j)
    #Appending final text
    final_text = ""
    for link in links:
      try:
        downloaded = trafilatura.fetch_url(link)
        final_text= final_text + "/n " + trafilatura.extract(downloaded)
      except:
        pass
  except Exception as e:
    print(e)
    final_text = ""
  return final_text

#Functionn to create chunks
def split_string(text,chunk_size,overlap):
    # Initialize an empty list to store the chunks
    chunks = []
    # Split the text into chunks of size chunk_size with an overlap of overlap
    for i in range(0, len(text), chunk_size - overlap):
        chunk = text[i:i + chunk_size]
        chunks.append(chunk)
    return chunks

# Function to preprocess text
def preprocess_text(text):
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    words = text.split()
    words = [word for word in words if word not in stop_words]
    # Join words into a single string
    text = ' '.join(words)
    return text


def get_initial_base(chunk_size, overlap):
   #Reading the info from disk
    # Open the file for reading
    with open('documentation.txt', 'r', encoding="utf-8") as file:
      # Read the contents of the file
      contents = file.read()
      contents = contents.replace('\n', '')
      contents = contents.replace('/n', '')
      chunks = split_string(contents,chunk_size, overlap)
      processed_corpus = [preprocess_text(cor) for cor in chunks]

      corpus_embeddings = embedder.encode(processed_corpus, convert_to_tensor=True)
      return corpus_embeddings, chunks


#Function to obtain context with tf-idf
def obtain_context_tf_idf(query,N,documents):
  # Preprocess documents
  processed_documents = [preprocess_text(doc) for doc in documents]
  # Create TF-IDF vectorizer
  vectorizer = TfidfVectorizer()
  # Fit the vectorizer to the processed documents
  tfidf_matrix = vectorizer.fit_transform(processed_documents)
  # Vectorize the query
  processed_query = preprocess_text(query)
  query_vector = vectorizer.transform([processed_query])
  # Calculate cosine similarity between each document and the query
  from sklearn.metrics.pairwise import cosine_similarity
  similarity_scores = cosine_similarity(tfidf_matrix, query_vector)
  # Get the top N most similar documents
  top_documents = similarity_scores.argsort(axis=0)[-N:].flatten()
  top_documents = np.flip(top_documents)
  context = ""
  # Print the top N most similar documents
  for doc_idx in top_documents:
      context = context + documents[doc_idx]
  doc = Document(page_content=context)
  doc_context = []
  doc_context.append(doc)
  text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
  docs = text_splitter.split_documents(doc_context)
  return (docs, context)

def obtain_context_emb(queries,N,corpus):
  processed_corpus = [preprocess_text(cor) for cor in corpus]
  try:
      corpus_embeddings = embedder.encode(processed_corpus, convert_to_tensor=True)
      corpus_embeddings = torch.cat((base,  corpus_embeddings ), dim=0)
      new_corpus = base_chunks + corpus
  except:
      corpus_embeddings = base
      new_corpus = base_chunks
  # Query sentences:
  queries = [queries]
  # Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
  top_k = min(N, len(new_corpus))
  for query in queries:
      query_embedding = embedder.encode(preprocess_text(query), convert_to_tensor=True)
      # We use cosine-similarity and torch.topk to find the highest 5 scores
      cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
      top_results = torch.topk(cos_scores, k=top_k)
      context = ""
      for score, idx in zip(top_results[0], top_results[1]):
          context = context + new_corpus[idx]

  doc = Document(page_content=context)
  doc_context = []
  doc_context.append(doc)
  text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
  docs = text_splitter.split_documents(doc_context)
  return (docs, context)



"""no search and tf idf"""
#OPENAI with no search and tf idf
def qa_openai_nosearch_tf_idf(query,prompt,chunk_size,overlap,n_context):
    #Reading the info from disk
    # Open the file for reading
    with open('documentation.txt', 'r', encoding="utf-8") as file:
      # Read the contents of the file
      contents = file.read()
    #Cleaning text
    contents = contents.replace('\n', '')
    contents = contents.replace('/n', '')
    contents = contents + aditional_context
    #Split data into chunks
    chunks = split_string(contents,chunk_size,overlap)
    #Searching best context with tf-idf
    docs = obtain_context_tf_idf(query,n_context,chunks)[0]
    #include prompt
    prompt_template = prompt
    PROMPT = PromptTemplate(template=prompt_template, input_variables=["context", "question"])
    #obtain responnse
    chain = load_qa_chain(open_ai, chain_type="stuff", prompt=PROMPT)
    result = chain.run(input_documents=docs, question=query, return_only_outputs=True)
    result = result.replace('\n', '')
    result = result.replace('/n', '')
    return result

"""no search and word embeddings"""
#OPENAI with no search and tf idf
def qa_openai_nosearch_emb(query,prompt,chunk_size,overlap,n_context):
    #Reading the info from disk
    # Open the file for reading
    with open('documentation.txt', 'r', encoding="utf-8") as file:
      # Read the contents of the file
      contents = file.read()
    #Cleaning text
    contents = contents.replace('\n', '')
    contents = contents.replace('/n', '')
    contents = contents + aditional_context
    #Split data into chunks
    chunks = split_string(contents,chunk_size,overlap)
    #Searching best context with tf-idf
    docs = obtain_context_emb(query,n_context,chunks)[0]
    #include prompt
    prompt_template = prompt
    PROMPT = PromptTemplate(template=prompt_template, input_variables=["context", "question"])
    #obtain responnse
    chain = load_qa_chain(open_ai, chain_type="stuff", prompt=PROMPT)
    result = chain.run(input_documents=docs, question=query, return_only_outputs=True)
    result = result.replace('\n', '')
    result = result.replace('/n', '')
    return result

"""search and tf idf"""
#OPENAI with search and tf idf
def qa_openai_search_tf_idf(query,prompt,chunk_size,overlap,n_context):
    #Search in internet
    internet_text= search_internet(query)
    #Reading the info from disk
    # Open the file for reading
    with open('documentation.txt', 'r', encoding="utf-8") as file:
      # Read the contents of the file
      contents = file.read()
    #Cleaning text
    contents = contents + internet_text
    contents = contents.replace('\n', '')
    contents = contents.replace('/n', '')
    contents = contents + aditional_context
    #Split data into chunks
    chunks = split_string(contents,chunk_size,overlap)
    #Searching best context with tf-idf
    docs = obtain_context_tf_idf(query,n_context,chunks)[0]
    print()
   #include prompt
    prompt_template = prompt
    PROMPT = PromptTemplate(template=prompt_template, input_variables=["context", "question"])
    #obtain responnse
    chain = load_qa_chain(open_ai, chain_type="stuff", prompt=PROMPT)
    result = chain.run(input_documents=docs, question=query, return_only_outputs=True)
    result = result.replace('\n', '')
    result = result.replace('/n', '')
    return result

"""search and word embeddings"""
#OPENAI with search and tf idf
def qa_openai_search_emb(query,prompt,chunk_size,overlap,n_context):
    try:
      # Search in internet
      internet_text = search_internet(query)
      contents = internet_text

      # Cleaning text
      contents = contents + internet_text
      contents = contents.replace('\n', '')
      contents = contents.replace('/n', '')


      # Split data into chunks
      chunks = split_string(contents, chunk_size, overlap)
      # Searching best context with tf-idf

      docs = obtain_context_emb(query, n_context, chunks)[0]

      #include prompt
      prompt_template = prompt
      PROMPT = PromptTemplate(template=prompt_template, input_variables=["context", "question"])
      #obtain responnse
      chain = load_qa_chain(open_ai, chain_type="stuff", prompt=PROMPT)
      result = chain.run(input_documents=docs, question=query, return_only_outputs=True)
      result = result.replace('\n', '')
      result = result.replace('/n', '')
      return result

    except Exception as e:
      print(e)
      return "I can't answer this question, please try other"

# %% [markdown]
# # query

# %%
prompt = """
Use the following pieces of context to answer the question at the end. Expand the answer with your own knowledge if required.

Context: {context}

Question: {question}

Answer:
"""
query_s = """
Which mechanism within the control plane is utilized to impose particular configurations in the Security Context?
"""

# %%
import gc
torch.cuda.empty_cache()
gc.collect()

chunk_size = 1000
overlap = 100
n_context = 5

get_base = get_initial_base(chunk_size, overlap)
base = get_base[0]
base_chunks =  get_base[1]

# %% [markdown]
# # Results for search and word embeddings

# %%
#Openai emb
search_openai_emb = qa_openai_search_emb(query =query_s,prompt = prompt,chunk_size = 1000,overlap = 100, n_context= 3)
search_openai_emb
# Out:
# 'The control plane utilizes the configuration API server to distribute particular configurations in the Security Context.'

# %% [markdown]
# # Evaluation
#
# ##QA answering dataset

# %%
prompt = """
You are a chatbot named SUESIE
Your purpose is to assist users in how to use Kubernetes
Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer

Context: {context}

Question: {question}

Expand with your own knowledge the answer and try to give examples if required.
Answer:
"""

# %%
import pandas as pd
df = pd.read_csv("qa_test_dataset - qa_test_dataset_review.csv", sep=';' )
df
# Out:
#                                              Question  \
# 0   Is the number of arguments specified by the co...
# 1                           What does GKE stands for?
# 2   Which mechanism within the control plane is ut...
# 3   How is called a non-terminating loop that regu...
# 4   Which specific command is capable of producing...
# 5   Which command is utilized to display Persisten...
# 6   Which command is utilized to retrieve the logs...
# 7   Why kubectl get rc --namespace=”<namespace_nam...
# 8   Provide a catalog of the different services th...
# 9           What are the distinct Kubernetes objects?
# 10  What are the three modes of Pod Security Admis...
# 11  Name the initial namespaces from which Kuberne...
# 12                                What is Kubernetes?
# 13                             Define what is kubelet
# 14  What is the relationship between Kubernetes an...
# 15                       What is a pod in kubernetes?
# ...

# %% [markdown]
# Posible combination list
#
# models_list = [qa_openai_nosearch_emb,qa_openai_search_emb ]
#
# chunk_sizes = [8000,4000,2000,1000]
#
# chunk_overlaps = [100]
#
# number_context_pages = [10,5,3,1]

# %%
import pickle

#Load a dict
try:
  with open('saved_dictionary_openai.pkl', 'rb') as f:
      dic_df = pickle.load(f)
except:
  dic_df={}
dfx = df.copy()
# %load_ext google.colab.data_table
def answer_df(row):
  try:
    res = modelz(query = row["Question"], prompt = prompt,chunk_size = chunk_size,overlap = chunk_overlap, n_context= number_context_page )
    print(len(row["Question"]))
    print(res)
    return res
  except:
    return ""
models_list = [qa_openai_search_emb ]
chunk_sizes = [8000,4000,2000,1000]
chunk_overlaps = [100]
number_context_pages = [10,5,3,1]

for modelz in models_list:
  for chunk_size in chunk_sizes:
    for number_context_page in number_context_pages:
      for chunk_overlap in chunk_overlaps:

        torch.cuda.empty_cache()
        df = pd.read_csv("qa_test_dataset - qa_test_dataset_review.csv", sep=';' )
        dfx_df = df.copy()





        get_base = get_initial_base(chunk_size, chunk_overlap)
        base = get_base[0]
        base_chunks =  get_base[1]


        if (chunk_size == 2000 and number_context_page >= 7):
              break
        if (chunk_size == 4000 and number_context_page >= 5):
              break
        if (chunk_size == 8000 and number_context_page >= 3):
              break
        key_name = "qa_flant5_search_emb chunk_size:" + str(chunk_size) + " chunk_overlap:" + str(chunk_overlap) + " conntext_pages:" + str(number_context_page)
        print(key_name)
        try:
          if key_name not in dic_df:
            dfx_df['Answer_generated']  = df.apply(answer_df, axis=1)
            dic_df[key_name]= dfx_df
            #Save a dict

            with open('saved_dictionary_openai.pkl', 'wb') as f:
                pickle.dump(dic_df, f)
            print(dfx_df)

        except:
          print("tokens exceeded")
# Out:
# qa_flant5_search_emb chunk_size:8000 chunk_overlap:100 conntext_pages:1
# 79
# No, the number of arguments specified by the configuration file for a Pod is not fixed. The configuration file for a Pod can contain a variety of arguments, such as the container image, command, arguments, environment variables, and more. The number and type of arguments will depend on the specific needs of the application running in the Pod. For example, a Pod running a web server may require different arguments than a Pod running a database. It is important to carefully consider and configure the arguments for each Pod to ensure it runs correctly and efficiently.
# 25
# ...
